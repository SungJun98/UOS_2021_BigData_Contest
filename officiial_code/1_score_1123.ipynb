# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# %%
os.chdir('/content/drive/My Drive/contest/data')

# %%
data=pd.read_csv('data2.csv',encoding='CP949')
data
# Out:
#   Unnamed: 0  vehicle_regis   traffic  container  storage_fluid  spare_fluid
# 0        수도권        1344643  15874324       2046          87200        59056
# 1         강원         160314   2707980        130           3500           60
# 2       대전충청         486218   6482369        448          38000        64120
# 3         전북         187902   1691142        151          16000        12874
# 4       대구경북         486218   4194019        312          46000        36823
# 5       광주전남         338917   2906422        353              0        17492
# 6       부산경남         549618   7740029       1091          47990       111385

# %%
data.columns=['regions','vehicle_regis', 'traffic','container', 'storage_fluid','spare_fluid']
data
# Out:
#   regions  vehicle_regis   traffic  container  storage_fluid  spare_fluid
# 0     수도권        1344643  15874324       2046          87200        59056
# 1      강원         160314   2707980        130           3500           60
# 2    대전충청         486218   6482369        448          38000        64120
# 3      전북         187902   1691142        151          16000        12874
# 4    대구경북         486218   4194019        312          46000        36823
# 5    광주전남         338917   2906422        353              0        17492
# 6    부산경남         549618   7740029       1091          47990       111385

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
data1=pd.DataFrame(sc.fit_transform(data.iloc[:,1:]),index=data.regions,columns=data.columns[1:])
data1
# Out:
#          vehicle_regis   traffic  container  storage_fluid  spare_fluid
# regions
# 수도권           2.266428  2.197636   2.170888       1.878066     0.449054
# 강원           -0.940677 -0.715658  -0.802858      -1.082196    -1.212923
# 대전충청         -0.058145  0.119494  -0.309303       0.137984     0.591712
# 전북           -0.865970 -0.940652  -0.770265      -0.640102    -0.851940
# 대구경북         -0.058145 -0.386845  -0.520383       0.420924    -0.177272
# 광주전남         -0.457029 -0.671749  -0.456749      -1.205982    -0.721846
# 부산경남          0.113539  0.397775   0.688671       0.491305     1.923215

# %%
data1['score']=data1['vehicle_regis']+data1['traffic']+data1['container']-data1['storage_fluid']-data1['spare_fluid']
data1
# Out:
#          vehicle_regis   traffic  ...  spare_fluid     score
# regions                           ...
# 수도권           2.266428  2.197636  ...     0.449054  4.307832
# 강원           -0.940677 -0.715658  ...    -1.212923 -0.164075
# 대전충청         -0.058145  0.119494  ...     0.591712 -0.977650
# 전북           -0.865970 -0.940652  ...    -0.851940 -1.084846
# 대구경북         -0.058145 -0.386845  ...    -0.177272 -1.209026
# 광주전남         -0.457029 -0.671749  ...    -0.721846  0.342301
# 부산경남          0.113539  0.397775  ...     1.923215 -1.214536
#
# [7 rows x 6 columns]

# %%
np.exp(data1['score'])/np.exp(data1['score']).sum()
# Out:
# regions
# 수도권     0.954187
# 강원      0.010902
# 대전충청    0.004833
# 전북      0.004341
# 대구경북    0.003834
# 광주전남    0.018089
# 부산경남    0.003813
# Name: score, dtype: float64
